# %% [markdown]
# <a href="https://colab.research.google.com/github/yuki-tamaribuchi/ml_code_kata/blob/master/word2vec_livedoornews.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !cp /content/drive/MyDrive/ml_sample_data/pickles/livedoor_news.pkl /content/

# %%
pip install janome

# %%
import pandas as pd
import numpy as np
from janome.tokenizer import Tokenizer

from gensim.models import Word2Vec

# %%
df=pd.read_pickle('livedoor_news.pkl')

tokenizer=Tokenizer(wakati=True)


texts=[]

for text in df[3]:
  texts.append(list(tokenizer.tokenize(text)))


sentences=[]
for text in texts:
  sentences.append(text)

# %%
 sentences
# Out:
# [['寝る',
#   'とき',
#   'に',
#   '？',
#   '移動',
#   '中',
#   'に',
#   '？',
#   '実は',
#   '使い',
#   'にくい',
#   'と',
#   'の',
#   '声',
#   'も',
#   '多い',
#   'iPad',
#   'の',
#   'お',
#   'ススメ',
#   '利用',
#   '法',
#   '【',
#   '話題',
#   '】'],
#  ['重',
#   'さ',
#   'で',
#   '容量',
#   'が',
#   'わかる',
#   '！',
#   'コンクリート',
#   'で',
#   'でき',
#   'た',
#   'USB',
#   'が',
#   'おもしろい',
#   '！',
#   '！',
#   '【',
#   '話題',
#   '】'],
#  ['盗',
#   '撮',
#   '現場',
#   'を',
#   '配信',
#   '!?',
#   '無料',
#   'イベント',
#   '中継',
#   'の',
#   'はず',
#   'が',
#   '衝撃',
#   '的',
#   '瞬間',
#   'が',
#   '発覚',
#   '【',
#   '話題',
#   '】'],
#  ['ソニー',
#   '、',
#   '１',
#   '０',
#   '倍',
#   'ズーム',
#   'で',
#   '３',
#   '．',
#   '０',
#   '型',
#   'タッチパネル',
#   '搭載',
#   'の',
#   '“',
#   'サイバーショット',
#   '”',
#   '「',
#   'ＤＳＣ',
#   '−',
#   'ＷＸ',
#   '１',
#   '７',
#   '０',
#   '」',
#   'を',
#   '発売',
#   '【',
#   '売れ筋',
#   'チェック',
#   '】'],
#  ['２',
#   '０',
#   '１',
#   '２',
#   '年',
#   'は',
#   'オシャレ',
# ...

# %%
model=Word2Vec(sentences,sg=1,size=100,window=5,min_count=1)

# %%
for i in model.most_similar('家族'):
  print(i)
# Out:
# ('料理', 0.9952366352081299)
# ('明らか', 0.9949815273284912)
# ('判明', 0.9948781132698059)
# ('すべて', 0.994368851184845)
# ('メイク', 0.993533730506897)
# ('復活', 0.9933184385299683)
# ('驚き', 0.9932485222816467)
# ('身', 0.9930518269538879)
# ('やっぱり', 0.9927753210067749)
# ('すごい', 0.9926477074623108)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.

# %%
#全くだめだ
